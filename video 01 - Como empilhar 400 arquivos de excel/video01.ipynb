# %%
import pandas as pd 
import numpy as np 
import glob

# %%
lista_arquivo=[]
for arquivo in glob.glob(r"C:\Users\renat\OneDrive\Documentos\Renata\Estudo\Trabalho Inteligente\VÍDEOS\video01\teste\*xls"):
    lista_arquivo.append(arquivo)

# %%
lista_arquivo
# Out:
# ['C:\\Users\\renat\\OneDrive\\Documentos\\Renata\\Estudo\\Trabalho Inteligente\\VÍDEOS\\video01\\teste\\compras_0.xls',
#  'C:\\Users\\renat\\OneDrive\\Documentos\\Renata\\Estudo\\Trabalho Inteligente\\VÍDEOS\\video01\\teste\\compras_1.xls']

# %%
tabelas=[]
for arquivo in lista_arquivo:
    tabelas.append(pd.read_excel(arquivo,index_col=0))

# %%
tabelas
# Out:
# [           valor_compra
#  id_compra
#  0                  4247
#  100                5500
#  200                 800
#  300                6397
#  400                6942
#  ...                 ...
#  99500              1493
#  99600              2524
#  99700              3921
#  99800              6207
#  99900              9604
#
#  [1000 rows x 1 columns],            valor_compra
#  id_compra
#  0                  6823
#  101                8191
#  202                6103
#  303                3149
#  404                3509
#  ...                 ...
#  100495              432
#  100596             2494
#  100697             3918
#  100798             3131
#  100899             3356
#
#  [1000 rows x 1 columns]]

# %%
tabela_final=pd.concat(tabelas)

# %%
tabela_final
# Out:
#            valor_compra
# id_compra
# 0                  4247
# 100                5500
# 200                 800
# 300                6397
# 400                6942
# ...                 ...
# 100495              432
# 100596             2494
# 100697             3918
# 100798             3131
# 100899             3356
#
# [2000 rows x 1 columns]

# %%
lista_arquivo=[]
for arquivo in glob.glob(r"C:\Users\renat\OneDrive\Documentos\Renata\Estudo\Trabalho Inteligente\VÍDEOS\video01\Tabelas\*xls"):
    lista_arquivo.append(arquivo)

# %%
lista_arquivo
# Out:
# ['C:\\Users\\renat\\OneDrive\\Documentos\\Renata\\Estudo\\Trabalho Inteligente\\VÍDEOS\\video01\\Tabelas\\compras_0.xls',
#  'C:\\Users\\renat\\OneDrive\\Documentos\\Renata\\Estudo\\Trabalho Inteligente\\VÍDEOS\\video01\\Tabelas\\compras_1.xls',
#  'C:\\Users\\renat\\OneDrive\\Documentos\\Renata\\Estudo\\Trabalho Inteligente\\VÍDEOS\\video01\\Tabelas\\compras_10.xls',
#  'C:\\Users\\renat\\OneDrive\\Documentos\\Renata\\Estudo\\Trabalho Inteligente\\VÍDEOS\\video01\\Tabelas\\compras_100.xls',
#  'C:\\Users\\renat\\OneDrive\\Documentos\\Renata\\Estudo\\Trabalho Inteligente\\VÍDEOS\\video01\\Tabelas\\compras_101.xls',
#  'C:\\Users\\renat\\OneDrive\\Documentos\\Renata\\Estudo\\Trabalho Inteligente\\VÍDEOS\\video01\\Tabelas\\compras_102.xls',
#  'C:\\Users\\renat\\OneDrive\\Documentos\\Renata\\Estudo\\Trabalho Inteligente\\VÍDEOS\\video01\\Tabelas\\compras_103.xls',
# ...

# %%
tabelas=[]
for arquivo in lista_arquivo:
    tabelas.append(pd.read_excel(arquivo,index_col=0))

# %%
tabela_final=pd.concat(tabelas)

# %%
2
# Out:
#            valor_compra
# id_compra
# 0                  4247
# 100                5500
# 200                 800
# 300                6397
# 400                6942
# ...                 ...
# 198005             6586
# 198204             8681
# 198403             3029
# 198602             9391
# 198801             6021
#
# [400000 rows x 1 columns]
